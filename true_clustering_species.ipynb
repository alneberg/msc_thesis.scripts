# %%
import pandas as pd
import matplotlib as mpl

# %matplotlib inline

# %%
df = pd.read_table("data/contig_count_per_genome_species.tsv", index_col=0)
df.head()
# Out:
#                    unamb_read_count_gi|10954629|ref|NC_001399.1|_Ralstonia_solanacearum_M4S_plasmid_pJTPS1,_complete_sequence  \
# contig
# contig-2003662                                                   186
# contig-3003765                                                     0
# contig-3003768                                                    14
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|110801439|ref|NC_008262.1|_Clostridium_perfringens_SM101_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|194246403|ref|NC_011047.1|_Candidatus_Phytoplasma_mali_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|352683411|ref|NC_016077.1|_Acidaminococcus_intestini_RyC-MR95_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|119025018|ref|NC_008618.1|_Bifidobacterium_adolescentis_ATCC_15703_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|150006674|ref|NC_009615.1|_Parabacteroides_distasonis_ATCC_8503_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|150014892|ref|NC_009617.1|_Clostridium_beijerinckii_NCIMB_8052_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|152979768|ref|NC_009659.1|_Janthinobacterium_sp._Marseille_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|332159624|ref|NC_015224.1|_Yersinia_enterocolitica_subsp._palearctica_105.5R_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    unamb_read_count_gi|160878162|ref|NC_010001.1|_Clostridium_phytofermentans_ISDg_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                              17832
# contig-1001988.34                                              17052
#
#                                                                     ...                                                     \
# contig                                                              ...
# contig-2003662                                                      ...
# contig-3003765                                                      ...
# contig-3003768                                                      ...
# contig-1001988.36                                                   ...
# contig-1001988.34                                                   ...
#
#                    amb_read_count_gi|507383177|ref|NC_021284.1|_Spiroplasma_syrphidicola_EA-1,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|509152352|ref|NC_021354.1|_Erysipelothrix_rhusiopathiae_SY1027,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|51593942|ref|NC_006154.1|_Yersinia_pseudotuberculosis_IP_32953_plasmid_pYptb32953,_complete_sequence  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|525905724|ref|NC_021832.1|_Spiroplasma_taiwanense_CT-1_plasmid,_complete_sequence  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|525908085|ref|NC_021833.1|_Spiroplasma_diminutum_CUAS-1,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|56899872|ref|NC_006578.1|_Bacillus_thuringiensis_serovar_konkukian_str._97-27_plasmid_pBT9727,_complete_sequence  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|58036264|ref|NC_004307.2|_Bifidobacterium_longum_NCC2705_chromosome,_complete_genome  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|67078390|ref|NC_007107.1|_Bacillus_cereus_E33L_plasmid_pE33L9,_complete_sequence  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|94972398|ref|NC_008014.1|_Lawsonia_intracellularis_PHE/MN1-00_plasmid_3,_complete_sequence  \
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
#                    amb_read_count_gi|150002608|ref|NC_009614.1|_Bacteroides_vulgatus_ATCC_8482_chromosome,_complete_genome
# contig
# contig-2003662                                                     0
# contig-3003765                                                     0
# contig-3003768                                                     0
# contig-1001988.36                                                  0
# contig-1001988.34                                                  0
#
# [5 rows x 202 columns]

# %%
val_cols_all = list(df.columns)
val_cols = []
for col in val_cols_all:
    if not col.startswith('amb_read_count'):
        val_cols.append(col)
val_cols
# Out:
# ['unamb_read_count_gi|10954629|ref|NC_001399.1|_Ralstonia_solanacearum_M4S_plasmid_pJTPS1,_complete_sequence',
#  'unamb_read_count_gi|110801439|ref|NC_008262.1|_Clostridium_perfringens_SM101_chromosome,_complete_genome',
#  'unamb_read_count_gi|194246403|ref|NC_011047.1|_Candidatus_Phytoplasma_mali_chromosome,_complete_genome',
#  'unamb_read_count_gi|352683411|ref|NC_016077.1|_Acidaminococcus_intestini_RyC-MR95_chromosome,_complete_genome',
#  'unamb_read_count_gi|119025018|ref|NC_008618.1|_Bifidobacterium_adolescentis_ATCC_15703_chromosome,_complete_genome',
#  'unamb_read_count_gi|150006674|ref|NC_009615.1|_Parabacteroides_distasonis_ATCC_8503_chromosome,_complete_genome',
#  'unamb_read_count_gi|150014892|ref|NC_009617.1|_Clostridium_beijerinckii_NCIMB_8052_chromosome,_complete_genome',
#  'unamb_read_count_gi|152979768|ref|NC_009659.1|_Janthinobacterium_sp._Marseille_chromosome,_complete_genome',
#  'unamb_read_count_gi|332159624|ref|NC_015224.1|_Yersinia_enterocolitica_subsp._palearctica_105.5R_chromosome,_complete_genome',
#  'unamb_read_count_gi|160878162|ref|NC_010001.1|_Clostridium_phytofermentans_ISDg_chromosome,_complete_genome',
#  'unamb_read_count_gi|162446888|ref|NC_010163.1|_Acholeplasma_laidlawii_PG-8A_chromosome,_complete_genome',
#  'unamb_read_count_gi|170780462|ref|NC_010407.1|_Clavibacter_michiganensis_subsp._sepedonicus_chromosome,_complete_genome',
#  'unamb_read_count_gi|187734516|ref|NC_010655.1|_Akkermansia_muciniphila_ATCC_BAA-835_chromosome,_complete_genome',
#  'unamb_read_count_gi|313202490|ref|NC_014734.1|_Paludibacter_propionicigenes_WB4_chromosome,_complete_genome',
#  'unamb_read_count_gi|188993864|ref|NC_010729.1|_Porphyromonas_gingivalis_ATCC_33277,_complete_genome',
#  'unamb_read_count_gi|479210985|ref|NC_021043.1|_Eubacterium_siraeum_V10Sc8a_draft_genome',
#  'unamb_read_count_gi|19703352|ref|NC_003454.1|_Fusobacterium_nucleatum_subsp._nucleatum_ATCC_25586_chromosome,_complete_genome',
#  'unamb_read_count_gi|479176048|ref|NC_021022.1|_Ruminococcus_obeum_A2-162_draft_genome',
#  'unamb_read_count_gi|220927459|ref|NC_011898.1|_Clostridium_cellulolyticum_H10_chromosome,_complete_genome',
#  'unamb_read_count_gi|226309587|ref|NC_012491.1|_Brevibacillus_brevis_NBRC_100599,_complete_genome',
#  'unamb_read_count_gi|237806776|ref|NC_012691.1|_Tolumonas_auensis_DSM_9187_chromosome,_complete_genome',
#  'unamb_read_count_gi|238915976|ref|NC_012778.1|_Eubacterium_eligens_ATCC_27750_chromosome,_complete_genome',
#  'unamb_read_count_gi|238922432|ref|NC_012781.1|_Eubacterium_rectale_ATCC_33656,_complete_genome',
#  'unamb_read_count_gi|255529916|ref|NC_013061.1|_Pedobacter_heparinus_DSM_2366_chromosome,_complete_genome',
#  'unamb_read_count_gi|257074450|ref|NC_013190.1|_Candidatus_Accumulibacter_phosphatis_clade_IIA_str._UW-1_plasmid_pAph02,_complete_sequence',
#  'unamb_read_count_gi|327312315|ref|NC_015311.1|_Prevotella_denticola_F0289_chromosome,_complete_genome',
#  'unamb_read_count_gi|258513366|ref|NC_013216.1|_Desulfotomaculum_acetoxidans_DSM_771_chromosome,_complete_genome',
#  'unamb_read_count_gi|260685375|ref|NC_013316.1|_Clostridium_difficile_R20291_chromosome,_complete_genome',
#  'unamb_read_count_gi|284047386|ref|NC_013740.1|_Acidaminococcus_fermentans_DSM_20731_chromosome,_complete_genome',
#  'unamb_read_count_gi|291464753|ref|NC_007971.2|_Cupriavidus_metallidurans_CH34_plasmid_pMOL30,_complete_sequence',
#  'unamb_read_count_gi|29611500|ref|NC_004703.1|_Bacteroides_thetaiotaomicron_VPI-5482_plasmid_p5482,_complete_sequence',
#  'unamb_read_count_gi|300309346|ref|NC_014323.1|_Herbaspirillum_seropedicae_SmR1_chromosome,_complete_genome',
#  'unamb_read_count_gi|302344773|ref|NC_014370.1|_Prevotella_melaninogenica_ATCC_25845_chromosome_I,_complete_sequence',
#  'unamb_read_count_gi|431792069|ref|NC_019903.1|_Desulfitobacterium_dichloroeliminans_LMG_P-21439_chromosome,_complete_genome',
#  'unamb_read_count_gi|302381116|ref|NC_014375.1|_Brevundimonas_subvibrioides_ATCC_15264_chromosome,_complete_genome',
#  'unamb_read_count_gi|302384444|ref|NC_014376.1|_Clostridium_saccharolyticum_WM1_chromosome,_complete_genome',
#  'unamb_read_count_gi|302872922|ref|NC_014393.1|_Clostridium_cellulovorans_743B_chromosome,_complete_genome',
#  'unamb_read_count_gi|310657316|ref|NC_014614.1|_Clostridium_sticklandii,_complete_genome',
#  'unamb_read_count_gi|315121750|ref|NC_014774.1|_Candidatus_Liberibacter_solanacearum_CLso-ZC1_chromosome,_complete_genome',
#  'unamb_read_count_gi|315499382|ref|NC_014817.1|_Asticcacaulis_excentricus_CB_48_chromosome_2,_complete_sequence',
#  'unamb_read_count_gi|317054731|ref|NC_014833.1|_Ruminococcus_albus_7_chromosome,_complete_genome',
#  'unamb_read_count_gi|325278757|ref|NC_015160.1|_Odoribacter_splanchnicus_DSM_20712_chromosome,_complete_genome',
#  'unamb_read_count_gi|317131008|ref|NC_014828.1|_Ethanoligenens_harbinense_YUAN-3_chromosome,_complete_genome',
#  'unamb_read_count_gi|325102757|ref|NC_015177.1|_Pedobacter_saltans_DSM_12145_chromosome,_complete_genome',
#  'unamb_read_count_gi|326797444|ref|NC_015277.1|_Sphingobacterium_sp._21_chromosome,_complete_genome',
#  'unamb_read_count_gi|479146200|ref|NC_021012.1|_Roseburia_intestinalis_XB6B4_draft_genome',
#  'unamb_read_count_gi|328954613|ref|NC_015389.1|_Coriobacterium_glomerans_PW2_chromosome,_complete_genome',
#  'unamb_read_count_gi|330837866|ref|NC_015437.1|_Selenomonas_sputigena_ATCC_35185_chromosome,_complete_genome',
#  'unamb_read_count_gi|331703020|ref|NC_015431.1|_Mycoplasma_mycoides_subsp._capri_LC_str._95010,_complete_genome',
#  'unamb_read_count_gi|339441064|ref|NC_015737.1|_Clostridium_sp._SY8519,_complete_genome',
#  'unamb_read_count_gi|390945347|ref|NC_018011.1|_Alistipes_finegoldii_DSM_17242_chromosome,_complete_genome',
#  'unamb_read_count_gi|340620745|ref|NC_015845.1|_Enterococcus_hirae_ATCC_9790_plasmid_pTG9790,_complete_sequence',
#  'unamb_read_count_gi|482887500|ref|NC_021083.1|_Mycoplasma_putrefaciens_Mput9231,_complete_genome',
#  'unamb_read_count_gi|342162671|ref|NC_015875.1|_Streptococcus_pseudopneumoniae_IS7493_chromosome,_complete_genome',
#  'unamb_read_count_gi|345428590|ref|NC_015964.1|_Haemophilus_parainfluenzae_T3T1,_complete_genome',
#  'unamb_read_count_gi|348025247|ref|NC_015873.1|_Megasphaera_elsdenii_DSM_20460,_complete_genome',
#  'unamb_read_count_gi|349703191|ref|NC_016046.1|_Oscillibacter_valericigenes_Sjm18-20_plasmid_pOBV01,_complete_sequence',
#  'unamb_read_count_gi|352516173|ref|NC_016052.1|_Tetragenococcus_halophilus_NBRC_12172,_complete_genome',
#  'unamb_read_count_gi|374294493|ref|NC_016627.1|_Clostridium_clariflavum_DSM_19732_chromosome,_complete_genome',
#  'unamb_read_count_gi|319899888|ref|NC_014933.1|_Bacteroides_helcogenes_P_36-108_chromosome,_complete_genome',
#  'unamb_read_count_gi|374307319|ref|NC_016630.1|_Filifactor_alocis_ATCC_35896_chromosome,_complete_genome',
#  'unamb_read_count_gi|375253814|ref|NC_016610.1|_Tannerella_forsythia_ATCC_43037_chromosome,_complete_genome',
#  'unamb_read_count_gi|383760671|ref|NC_017077.1|_Selenomonas_ruminantium_subsp._lactilytica_TAM6421_plasmid_pSRC7,_complete_sequence',
#  'unamb_read_count_gi|385777386|ref|NC_017304.1|_Clostridium_thermocellum_DSM_1313_chromosome,_complete_genome',
#  'unamb_read_count_gi|431795410|ref|NC_019904.1|_Echinicola_vietnamensis_DSM_17526_chromosome,_complete_genome',
#  'unamb_read_count_gi|386085705|ref|NC_017563.1|_Streptococcus_thermophilus_ND03_chromosome,_complete_genome',
#  'unamb_read_count_gi|386348020|ref|NC_017584.1|_Rhodospirillum_rubrum_F11_chromosome,_complete_genome',
#  'unamb_read_count_gi|387132089|ref|NC_017861.1|_Prevotella_intermedia_17_chromosome_chromosome_II,_complete_sequence',
#  'unamb_read_count_gi|72384244|ref|NC_007337.1|_Ralstonia_eutropha_JMP134_plasmid_1,_complete_sequence',
#  'unamb_read_count_gi|387816237|ref|NC_017299.1|_Clostridium_botulinum_H04402_065,_complete_genome',
#  'unamb_read_count_gi|387878539|ref|NC_017905.1|_Streptococcus_parasanguinis_FW213_chromosome,_complete_genome',
#  'unamb_read_count_gi|83588874|ref|NC_007644.1|_Moorella_thermoacetica_ATCC_39073_chromosome,_complete_genome',
#  'unamb_read_count_gi|407472532|ref|NC_018664.1|_Clostridium_acidurici_9a_chromosome,_complete_genome',
#  'unamb_read_count_gi|409101469|ref|NC_018867.1|_Dehalobacter_sp._CF_chromosome,_complete_genome',
#  'unamb_read_count_gi|427740400|ref|NC_019679.1|_Rivularia_sp._PCC_7116_plasmid_pRIV7116.01,_complete_sequence',
#  'unamb_read_count_gi|52421214|ref|NC_006297.1|_Bacteroides_fragilis_YCH46_plasmid_pBFY46,_complete_sequence',
#  'unamb_read_count_gi|434408147|ref|NC_019758.1|_Cylindrospermum_stagnale_PCC_7417_plasmid_pCYLST.03,_complete_sequence',
#  'unamb_read_count_gi|472465460|ref|NC_020887.1|_Clostridium_stercorarium_subsp._stercorarium_DSM_8532,_complete_genome',
#  'unamb_read_count_gi|479185170|ref|NC_021030.1|_Alistipes_shahii_WAL_8301_draft_genome',
#  'unamb_read_count_gi|479136967|ref|NC_021009.1|_Coprococcus_catus_GD/7_draft_genome',
#  'unamb_read_count_gi|479150083|ref|NC_021013.1|_Ruminococcus_bromii_L2-63_draft_genome',
#  'unamb_read_count_gi|479152295|ref|NC_021014.1|_Ruminococcus_sp._SR1/5_draft_genome',
#  'unamb_read_count_gi|479155735|ref|NC_021015.1|_Ruminococcus_torques_L2-14_draft_genome',
#  'unamb_read_count_gi|269797069|ref|NC_013520.1|_Veillonella_parvula_DSM_2008_chromosome,_complete_genome',
#  'unamb_read_count_gi|479158859|ref|NC_021016.1|_Butyrate-producing_bacterium_SSC/2,_complete_genome',
#  'unamb_read_count_gi|479166807|ref|NC_021018.1|_Coprococcus_sp._ART55/1_draft_genome',
#  'unamb_read_count_gi|479169109|ref|NC_021019.1|_Eubacterium_cylindroides_T2-87_draft_genome',
#  'unamb_read_count_gi|479170689|ref|NC_021020.1|_Faecalibacterium_prausnitzii_SL3/3_draft_genome',
#  'unamb_read_count_gi|479199283|ref|NC_021039.1|_Ruminococcus_champanellensis_18P13,_complete_genome',
#  'unamb_read_count_gi|479336697|ref|NC_021047.1|_Clostridium_cf._saccharolyticum_K10,_complete_genome',
#  'unamb_read_count_gi|50364815|ref|NC_006055.1|_Mesoplasma_florum_L1_chromosome,_complete_genome',
#  'unamb_read_count_gi|507383177|ref|NC_021284.1|_Spiroplasma_syrphidicola_EA-1,_complete_genome',
#  'unamb_read_count_gi|509152352|ref|NC_021354.1|_Erysipelothrix_rhusiopathiae_SY1027,_complete_genome',
#  'unamb_read_count_gi|51593942|ref|NC_006154.1|_Yersinia_pseudotuberculosis_IP_32953_plasmid_pYptb32953,_complete_sequence',
#  'unamb_read_count_gi|525905724|ref|NC_021832.1|_Spiroplasma_taiwanense_CT-1_plasmid,_complete_sequence',
#  'unamb_read_count_gi|525908085|ref|NC_021833.1|_Spiroplasma_diminutum_CUAS-1,_complete_genome',
#  'unamb_read_count_gi|56899872|ref|NC_006578.1|_Bacillus_thuringiensis_serovar_konkukian_str._97-27_plasmid_pBT9727,_complete_sequence',
#  'unamb_read_count_gi|58036264|ref|NC_004307.2|_Bifidobacterium_longum_NCC2705_chromosome,_complete_genome',
#  'unamb_read_count_gi|67078390|ref|NC_007107.1|_Bacillus_cereus_E33L_plasmid_pE33L9,_complete_sequence',
#  'unamb_read_count_gi|94972398|ref|NC_008014.1|_Lawsonia_intracellularis_PHE/MN1-00_plasmid_3,_complete_sequence',
#  'unamb_read_count_gi|150002608|ref|NC_009614.1|_Bacteroides_vulgatus_ATCC_8482_chromosome,_complete_genome']

# %%
df['total_nr_reads'] = df[val_cols].sum(axis=1)

# %%
taxon_short_names_d = {}
for col in sorted(val_cols):
    taxon_complete = col.split('|')[-1].split(',')[0] 
    if taxon_complete in taxon_short_names_d:
        print(taxon_short_names_d[taxon_complete])
    else:
        taxon_short_names_d[taxon_complete] = "_".join([x[0:3].upper() for x in taxon_complete.split('_')[1:3]])

# %%
taxon_short_names_d
# Out:
# {'_Acholeplasma_laidlawii_PG-8A_chromosome': 'ACH_LAI',
#  '_Acidaminococcus_fermentans_DSM_20731_chromosome': 'ACI_FER',
#  '_Acidaminococcus_intestini_RyC-MR95_chromosome': 'ACI_INT',
#  '_Akkermansia_muciniphila_ATCC_BAA-835_chromosome': 'AKK_MUC',
#  '_Alistipes_finegoldii_DSM_17242_chromosome': 'ALI_FIN',
#  '_Alistipes_shahii_WAL_8301_draft_genome': 'ALI_SHA',
#  '_Asticcacaulis_excentricus_CB_48_chromosome_2': 'AST_EXC',
#  '_Bacillus_cereus_E33L_plasmid_pE33L9': 'BAC_CER',
#  '_Bacillus_thuringiensis_serovar_konkukian_str._97-27_plasmid_pBT9727': 'BAC_THU',
#  '_Bacteroides_fragilis_YCH46_plasmid_pBFY46': 'BAC_FRA',
#  '_Bacteroides_helcogenes_P_36-108_chromosome': 'BAC_HEL',
#  '_Bacteroides_thetaiotaomicron_VPI-5482_plasmid_p5482': 'BAC_THE',
#  '_Bacteroides_vulgatus_ATCC_8482_chromosome': 'BAC_VUL',
#  '_Bifidobacterium_adolescentis_ATCC_15703_chromosome': 'BIF_ADO',
#  '_Bifidobacterium_longum_NCC2705_chromosome': 'BIF_LON',
#  '_Brevibacillus_brevis_NBRC_100599': 'BRE_BRE',
#  '_Brevundimonas_subvibrioides_ATCC_15264_chromosome': 'BRE_SUB',
#  '_Butyrate-producing_bacterium_SSC/2': 'BUT_BAC',
#  '_Candidatus_Accumulibacter_phosphatis_clade_IIA_str._UW-1_plasmid_pAph02': 'CAN_ACC',
#  '_Candidatus_Liberibacter_solanacearum_CLso-ZC1_chromosome': 'CAN_LIB',
#  '_Candidatus_Phytoplasma_mali_chromosome': 'CAN_PHY',
#  '_Clavibacter_michiganensis_subsp._sepedonicus_chromosome': 'CLA_MIC',
#  '_Clostridium_acidurici_9a_chromosome': 'CLO_ACI',
#  '_Clostridium_beijerinckii_NCIMB_8052_chromosome': 'CLO_BEI',
#  '_Clostridium_botulinum_H04402_065': 'CLO_BOT',
#  '_Clostridium_cellulolyticum_H10_chromosome': 'CLO_CEL',
#  '_Clostridium_cellulovorans_743B_chromosome': 'CLO_CEL',
#  '_Clostridium_cf._saccharolyticum_K10': 'CLO_CF.',
#  '_Clostridium_clariflavum_DSM_19732_chromosome': 'CLO_CLA',
#  '_Clostridium_difficile_R20291_chromosome': 'CLO_DIF',
#  '_Clostridium_perfringens_SM101_chromosome': 'CLO_PER',
#  '_Clostridium_phytofermentans_ISDg_chromosome': 'CLO_PHY',
#  '_Clostridium_saccharolyticum_WM1_chromosome': 'CLO_SAC',
#  '_Clostridium_sp._SY8519': 'CLO_SP.',
#  '_Clostridium_stercorarium_subsp._stercorarium_DSM_8532': 'CLO_STE',
#  '_Clostridium_sticklandii': 'CLO_STI',
#  '_Clostridium_thermocellum_DSM_1313_chromosome': 'CLO_THE',
#  '_Coprococcus_catus_GD/7_draft_genome': 'COP_CAT',
#  '_Coprococcus_sp._ART55/1_draft_genome': 'COP_SP.',
#  '_Coriobacterium_glomerans_PW2_chromosome': 'COR_GLO',
#  '_Cupriavidus_metallidurans_CH34_plasmid_pMOL30': 'CUP_MET',
#  '_Cylindrospermum_stagnale_PCC_7417_plasmid_pCYLST.03': 'CYL_STA',
#  '_Dehalobacter_sp._CF_chromosome': 'DEH_SP.',
#  '_Desulfitobacterium_dichloroeliminans_LMG_P-21439_chromosome': 'DES_DIC',
#  '_Desulfotomaculum_acetoxidans_DSM_771_chromosome': 'DES_ACE',
#  '_Echinicola_vietnamensis_DSM_17526_chromosome': 'ECH_VIE',
#  '_Enterococcus_hirae_ATCC_9790_plasmid_pTG9790': 'ENT_HIR',
#  '_Erysipelothrix_rhusiopathiae_SY1027': 'ERY_RHU',
#  '_Ethanoligenens_harbinense_YUAN-3_chromosome': 'ETH_HAR',
#  '_Eubacterium_cylindroides_T2-87_draft_genome': 'EUB_CYL',
#  '_Eubacterium_eligens_ATCC_27750_chromosome': 'EUB_ELI',
#  '_Eubacterium_rectale_ATCC_33656': 'EUB_REC',
#  '_Eubacterium_siraeum_V10Sc8a_draft_genome': 'EUB_SIR',
#  '_Faecalibacterium_prausnitzii_SL3/3_draft_genome': 'FAE_PRA',
#  '_Filifactor_alocis_ATCC_35896_chromosome': 'FIL_ALO',
#  '_Fusobacterium_nucleatum_subsp._nucleatum_ATCC_25586_chromosome': 'FUS_NUC',
#  '_Haemophilus_parainfluenzae_T3T1': 'HAE_PAR',
#  '_Herbaspirillum_seropedicae_SmR1_chromosome': 'HER_SER',
#  '_Janthinobacterium_sp._Marseille_chromosome': 'JAN_SP.',
#  '_Lawsonia_intracellularis_PHE/MN1-00_plasmid_3': 'LAW_INT',
#  '_Megasphaera_elsdenii_DSM_20460': 'MEG_ELS',
#  '_Mesoplasma_florum_L1_chromosome': 'MES_FLO',
#  '_Moorella_thermoacetica_ATCC_39073_chromosome': 'MOO_THE',
#  '_Mycoplasma_mycoides_subsp._capri_LC_str._95010': 'MYC_MYC',
#  '_Mycoplasma_putrefaciens_Mput9231': 'MYC_PUT',
#  '_Odoribacter_splanchnicus_DSM_20712_chromosome': 'ODO_SPL',
#  '_Oscillibacter_valericigenes_Sjm18-20_plasmid_pOBV01': 'OSC_VAL',
#  '_Paludibacter_propionicigenes_WB4_chromosome': 'PAL_PRO',
#  '_Parabacteroides_distasonis_ATCC_8503_chromosome': 'PAR_DIS',
#  '_Pedobacter_heparinus_DSM_2366_chromosome': 'PED_HEP',
#  '_Pedobacter_saltans_DSM_12145_chromosome': 'PED_SAL',
#  '_Porphyromonas_gingivalis_ATCC_33277': 'POR_GIN',
#  '_Prevotella_denticola_F0289_chromosome': 'PRE_DEN',
#  '_Prevotella_intermedia_17_chromosome_chromosome_II': 'PRE_INT',
#  '_Prevotella_melaninogenica_ATCC_25845_chromosome_I': 'PRE_MEL',
#  '_Ralstonia_eutropha_JMP134_plasmid_1': 'RAL_EUT',
#  '_Ralstonia_solanacearum_M4S_plasmid_pJTPS1': 'RAL_SOL',
#  '_Rhodospirillum_rubrum_F11_chromosome': 'RHO_RUB',
#  '_Rivularia_sp._PCC_7116_plasmid_pRIV7116.01': 'RIV_SP.',
#  '_Roseburia_intestinalis_XB6B4_draft_genome': 'ROS_INT',
#  '_Ruminococcus_albus_7_chromosome': 'RUM_ALB',
#  '_Ruminococcus_bromii_L2-63_draft_genome': 'RUM_BRO',
#  '_Ruminococcus_champanellensis_18P13': 'RUM_CHA',
#  '_Ruminococcus_obeum_A2-162_draft_genome': 'RUM_OBE',
#  '_Ruminococcus_sp._SR1/5_draft_genome': 'RUM_SP.',
#  '_Ruminococcus_torques_L2-14_draft_genome': 'RUM_TOR',
#  '_Selenomonas_ruminantium_subsp._lactilytica_TAM6421_plasmid_pSRC7': 'SEL_RUM',
#  '_Selenomonas_sputigena_ATCC_35185_chromosome': 'SEL_SPU',
#  '_Sphingobacterium_sp._21_chromosome': 'SPH_SP.',
#  '_Spiroplasma_diminutum_CUAS-1': 'SPI_DIM',
#  '_Spiroplasma_syrphidicola_EA-1': 'SPI_SYR',
#  '_Spiroplasma_taiwanense_CT-1_plasmid': 'SPI_TAI',
#  '_Streptococcus_parasanguinis_FW213_chromosome': 'STR_PAR',
#  '_Streptococcus_pseudopneumoniae_IS7493_chromosome': 'STR_PSE',
#  '_Streptococcus_thermophilus_ND03_chromosome': 'STR_THE',
#  '_Tannerella_forsythia_ATCC_43037_chromosome': 'TAN_FOR',
#  '_Tetragenococcus_halophilus_NBRC_12172': 'TET_HAL',
#  '_Tolumonas_auensis_DSM_9187_chromosome': 'TOL_AUE',
#  '_Veillonella_parvula_DSM_2008_chromosome': 'VEI_PAR',
#  '_Yersinia_enterocolitica_subsp._palearctica_105.5R_chromosome': 'YER_ENT',
#  '_Yersinia_pseudotuberculosis_IP_32953_plasmid_pYptb32953': 'YER_PSE'}

# %%
classification = df[(df[val_cols].max(axis=1) >= 10) & (df[val_cols].max(axis=1).divide(df['total_nr_reads']) > 0.500)][val_cols].idxmax(axis=1)
classification_df = pd.DataFrame(index=classification.index)
classification_df['taxon'] = classification.apply(lambda x: taxon_short_names_d[x.split('|')[-1].split(',')[0]])

# %%
classification_df['fraction_of_reads'] = df[val_cols].max(axis=1).divide(df['total_nr_reads'])
classification_df['total_nr_reads'] = df['total_nr_reads']

# %%
classification_df.head()
# Out:
#                      taxon  fraction_of_reads  total_nr_reads
# contig
# contig-2003662     RAL_SOL           1.000000             186
# contig-3003765     BAC_CER           0.591262           39918
# contig-3003768     RAL_SOL           1.000000              14
# contig-1001988.36  CLO_PHY           1.000000           17832
# contig-1001988.34  CLO_PHY           1.000000           17052

# %%
len(classification_df), len(df)
# Out:
# (40669, 41029)

# %%
classification_df.to_csv("data/true_clustering_species.csv", header=None)
